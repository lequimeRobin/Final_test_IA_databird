# %% [markdown]
# ## Chargement des packages

# %%
# !pip install --upgrade pip
# !pip install tensorflow==2.16.1
# !pip install gradio==3.39.0
# !pip install scikit-learn==1.4.2
# !pip install pandas==2.1.3
# !pip install matplotlib==3.8.0
# !pip install seaborn==0.12.2
# !pip install nltk==3.8.1
# !pip install scikit-learn==1.4.2
# !pip install transformers==4.37.2
# !pip install langchain==0.0.326
# !pip install datasets==2.16.1
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.12/site-packages (25.1.1)
# Requirement already satisfied: tensorflow==2.16.1 in /opt/anaconda3/lib/python3.12/site-packages (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (1.73.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.1) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.16.1) (0.44.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (13.7.1)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.1) (0.1.0)
# Requirement already satisfied: gradio==3.39.0 in /opt/anaconda3/lib/python3.12/site-packages (3.39.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (23.2.1)
# Requirement already satisfied: aiohttp~=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (3.10.5)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (5.0.1)
# Requirement already satisfied: fastapi in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.116.1)
# Requirement already satisfied: ffmpy in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.6.0)
# Requirement already satisfied: gradio-client>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (1.11.0)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.33.4)
# Requirement already satisfied: jinja2<4.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (3.1.4)
# Requirement already satisfied: markdown-it-py>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.39.0) (2.2.0)
# Requirement already satisfied: markupsafe~=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (3.8.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.3.0)
# Requirement already satisfied: numpy~=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (3.11.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (2.1.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (10.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (2.8.2)
# Requirement already satisfied: pydub in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.25.1)
# Requirement already satisfied: python-multipart in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (2.32.3)
# Requirement already satisfied: semantic-version~=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (0.35.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/anaconda3/lib/python3.12/site-packages (from gradio==3.39.0) (11.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp~=3.0->gradio==3.39.0) (1.11.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==3.39.0) (4.23.0)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==3.39.0) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.39.0) (2.9.0.post0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.0.0->markdown-it-py[linkify]>=2.0.0->gradio==3.39.0) (0.1.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==3.39.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==3.39.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.39.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.39.0) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.0->gradio==3.39.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.0->gradio==3.39.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.0->gradio==3.39.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.0->gradio==3.39.0) (2025.4.26)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from gradio-client>=0.3.0->gradio==3.39.0) (2023.10.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx->gradio==3.39.0) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx->gradio==3.39.0) (1.0.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from httpx->gradio==3.39.0) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx->gradio==3.39.0) (0.14.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.14.0->gradio==3.39.0) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.14.0->gradio==3.39.0) (4.66.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.14.0->gradio==3.39.0) (1.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.39.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.39.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.39.0) (0.10.6)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.39.0) (2.0.0)
# Requirement already satisfied: uc-micro-py in /opt/anaconda3/lib/python3.12/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.39.0) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==3.39.0) (1.16.0)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn>=0.14.0->gradio==3.39.0) (8.1.7)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi->gradio==3.39.0) (0.47.2)
# Requirement already satisfied: scikit-learn==1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (3.5.0)
# Requirement already satisfied: pandas==2.1.3 in /opt/anaconda3/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas==2.1.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.16.0)
# Requirement already satisfied: matplotlib==3.8.0 in /opt/anaconda3/lib/python3.12/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib==3.8.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.8.0) (1.16.0)
# Requirement already satisfied: seaborn==0.12.2 in /opt/anaconda3/lib/python3.12/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from seaborn==0.12.2) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /opt/anaconda3/lib/python3.12/site-packages (from seaborn==0.12.2) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/anaconda3/lib/python3.12/site-packages (from seaborn==0.12.2) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.25->seaborn==0.12.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.25->seaborn==0.12.2) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn==0.12.2) (1.16.0)
# Requirement already satisfied: nltk==3.8.1 in /opt/anaconda3/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk==3.8.1) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk==3.8.1) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk==3.8.1) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk==3.8.1) (4.66.5)
# Requirement already satisfied: scikit-learn==1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.4.2) (3.5.0)
# Collecting transformers==4.37.2
#   Using cached transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.37.2)
#   Using cached tokenizers-0.15.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.37.2) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2) (4.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.37.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.37.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.37.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.37.2) (2025.4.26)
# Using cached transformers-4.37.2-py3-none-any.whl (8.4 MB)
# Using cached tokenizers-0.15.2-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.2
#     Uninstalling tokenizers-0.21.2:
#       Successfully uninstalled tokenizers-0.21.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.3
#     Uninstalling transformers-4.53.3:
#       Successfully uninstalled transformers-4.53.3━━━━━━━━━━━━━━━━ 1/2 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers] [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.0.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.37.2 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.37.2
# Requirement already satisfied: langchain==0.0.326 in /opt/anaconda3/lib/python3.12/site-packages (0.0.326)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (3.10.5)
# Requirement already satisfied: anyio<4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (0.0.92)
# Requirement already satisfied: numpy<2,>=1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain==0.0.326) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.326) (1.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<4.0->langchain==0.0.326) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<4.0->langchain==0.0.326) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.326) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.326) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.0.326) (2.1)
# Requirement already satisfied: packaging>=17.0 in /opt/anaconda3/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.326) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.0.326) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.0.326) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.0.326) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.0.326) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.0.326) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.0.326) (2025.4.26)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.326) (1.0.0)
# Requirement already satisfied: datasets==2.16.1 in /opt/anaconda3/lib/python3.12/site-packages (2.16.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (1.26.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (0.7)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (0.3.7)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (2.1.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (4.66.5)
# Requirement already satisfied: xxhash in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (3.5.0)
# Requirement already satisfied: multiprocess in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.16.1) (2023.10.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (0.33.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets==2.16.1) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets==2.16.1) (1.11.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp->datasets==2.16.1) (3.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.4->datasets==2.16.1) (4.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.4->datasets==2.16.1) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.16.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.16.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.16.1) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets==2.16.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets==2.16.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets==2.16.1) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.16.1) (1.16.0)

# %%
import numpy as numpy
import pandas as pd
import keras as keras
import matplotlib.pyplot as plt
import seaborn as sns
import gradio as gr
from huggingface_hub import hf_hub_download
from datasets import load_dataset
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import HuggingFaceHub
from langchain.chains import RetrievalQA
from langchain.embeddings import SentenceTransformerEmbeddings
from transformers import pipeline
from langchain.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/gradio_client/documentation.py:106: UserWarning: Could not get documentation group for <class 'gradio.mix.Parallel'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# /opt/anaconda3/lib/python3.12/site-packages/gradio_client/documentation.py:106: UserWarning: Could not get documentation group for <class 'gradio.mix.Series'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")

# %% [markdown]
# ## Récupération du dataset
